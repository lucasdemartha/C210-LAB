# %% [markdown]
# # Algoritmos Genéticos

# %% [markdown]
#     ▪Ramo dos algoritmos evolucionários
#     ▪Técnica de busca baseada na metáfora do processo biológico de evolução natural.
#     ▪Populações de indivíduos são criadas e submetidas aos operadores genéticos:
#         ▪Seleção;
#         ▪Recombinação (crossover);
#         ▪Mutação;
#         ▪Elitismo.

# %% [markdown]
# ## Minimizando a equação X^2 + Y^2

# %% [markdown]
# ## Bitset

# %%
import numpy as np
import random

class BitSet:
    def __init__(self, size):
        self.bits = np.full((1, size), False)

    def get(self, index):
        return self.bits[0, index]

    def set(self, index, value):
        self.bits[0, index] = not value

    def flip(self, index):
        self.bits[0, index] = not self.bits[0, index]

    def debug(self):
        print(self.bits)

# %% [markdown]
# ## Cromossomo

# %%
class Chromossome:
    def __init__(self, x = None, y = None):
        if x == None:
            x = random.randint(-15, 15)

        if y == None:
            y = random.randint(-15, 15)

        self.__genes = Chromossome.get_genotype(x, y)

    def get_genes(self):
        return self.__genes

    def set_genes(self, genes):
        self.__genes = genes

    def to_string(self):
        chr_str = "G = ["

        for i in range(10):
            chr_str += (i == 5 and " " or "") + (self.__genes.get(i) and "1" or "0")

        x, y = Chromossome.get_fenotype(self.__genes)

        chr_str += "], F = [" + str(x) + ", " + str(y) + "]"

        return chr_str

    @staticmethod
    def get_genotype(x, y):
        bits = BitSet(10)

        xy_binary = "{:05b}".format(x) + "{:05b}".format(y)

        for i in range(10):
            bits.set(i, xy_binary[i] == '0')

        return bits

    @staticmethod
    def get_fenotype(genes):

            # xxxxx yyyyy (genótipo)
            # 01234 56789 (indices)
            # S8421 S8421 (s == 0 -> Positivo; s == 1 -> Negativo)
            # Ex : 11000 = -8        01000 = 8        11010 = -10         01010 = 10

        x = (8 * genes.get(1) +
         4 * genes.get(2) +
         2 * genes.get(3) +
         1 * genes.get(4))
    
        if genes.get(0) == 1:
            x *= -1

        y = (8 * genes.get(6) +
            4 * genes.get(7) +
            2 * genes.get(8) +
            1 * genes.get(9))
    
        if genes.get(5) == 1:
            y *= -1
            
        return x, y

# %% [markdown]
# ## Problema

# %%
class Problem:

    @staticmethod
    def f(x, y):
        return x**2 + y**2

    @staticmethod
    def f_chromossome(chromossome):   # verificando o resultado no fenotico
        genes = chromossome.get_genes()   # pegando o genotico ( binario )
        x, y = Chromossome.get_fenotype(genes) # com o binario ( gene ) pegando o fenotipo ( decimal )
        return Problem.f(x, y)

    @staticmethod
    def g(x, y):    # o maior eh o melhor cromossomo
        return 1 / (1 + Problem.f(x, y))

    @staticmethod
    def g_chromossome(chromossome):   # usado para achar o melhor cromossomo ( o maior valor que eh o melhor )
        genes = chromossome.get_genes()
        x, y = Chromossome.get_fenotype(genes)
        return Problem.g(x, y)

    @staticmethod
    def f_average(population):   # a media do score f
        avg = 0
        for chromossome in population:
            avg += Problem.f_chromossome(chromossome)
        avg /= len(population)
        return avg

    @staticmethod
    def g_average(population):  # a media do score g ( media score da populacao )
        avg = 0
        for chromossome in population:
            avg += Problem.g_chromossome(chromossome)
        avg /= len(population)
        return avg

# %% [markdown]
# ## Utils

# %%
class GeneticUtils:

    @staticmethod
    def find_best_chromossome(population):
        best_chromossome = None

        for chromossome in population:
            score = Problem.g_chromossome(chromossome)

            if best_chromossome is None or score > Problem.g_chromossome(best_chromossome):
                best_chromossome = chromossome

        return best_chromossome

    @staticmethod
    def find_worst_chromossome(population):
        worst_chromossome = None

        for chromossome in population:
            score = Problem.g_chromossome(chromossome)

            if worst_chromossome is None or score < Problem.g_chromossome(worst_chromossome):
                worst_chromossome = chromossome

        return worst_chromossome

    @staticmethod
    def format_chromossome(chromossome):
        return f"{chromossome.to_string()}, Score = {Problem.g_chromossome(chromossome):.3f}"

# %% [markdown]
# ## Genetic Operations

# %%
class GeneticOperators:

    MUTATION_PROBABILITY = 0.05   # probabilidade de acontecer alguma mutacao

    @staticmethod
    def selection(population):      # seleciona dois pais aleatorios
        parent1 = random.choice(population)
        parent2 = random.choice(population)

        while parent1 is parent2:               # verifica se sao iguais, gera ate serem diferentes
            parent1 = random.choice(population)
            parent2 = random.choice(population)

        print(f"1st parent chosen for crossover: {GeneticUtils.format_chromossome(parent1)}")
        print(f"2nd parent chosen for crossover: {GeneticUtils.format_chromossome(parent2)}")

        return parent1, parent2

    @staticmethod
    def crossover(population, parent1, parent2):      # adicionando dois filhos para a populacao
        crossover_point = random.randint(1, 9)
        print(f"Crossover will happen at point {crossover_point}")

        parent1_genes = parent1.get_genes()
        parent2_genes = parent2.get_genes()

        child1_genes = BitSet(10)
        child2_genes = BitSet(10)

        for i in range(0, crossover_point):     # crossover antes do corte   (0, 5)
            child1_genes.set(i, not parent1_genes.get(i)) # filho1 = (0,5) -> pai1
            child2_genes.set(i, not parent2_genes.get(i)) # filho2 = (0,5) -> pai2

        for i in range(crossover_point, 10): # crossover depois do corte
            child1_genes.set(i, not parent2_genes.get(i)) # filho1 = (6,9) -> pai2
            child2_genes.set(i, not parent1_genes.get(i)) # filho2 = (6,9) -> pai1

        child1 = Chromossome()
        child1.set_genes(child1_genes)
        print(f"1st child generated from crossover: {GeneticUtils.format_chromossome(child1)}")

        child2 = Chromossome()
        child2.set_genes(child2_genes)
        print(f"2nd child generated from crossover: {GeneticUtils.format_chromossome(child2)}")

        population.append(child1)
        population.append(child2)
        
    @staticmethod
    def mutation(population):
        prob = random.uniform(0, 1)

        if prob >= GeneticOperators.MUTATION_PROBABILITY:    # nao faz a mutacao
            return

        target = random.choice(population)

        mutation_point = random.randint(0, 9)
        print(f"Individual {target.to_string()} will mutate at point {mutation_point}")

        genes = target.get_genes()
        genes.flip(mutation_point)

        print(f"Individual {target.to_string()} mutated at point {mutation_point}")

    @staticmethod
    def elitism(population):            # retirando os dois piores cromossomos
        for _ in range(2):
            worst_individual = GeneticUtils.find_worst_chromossome(population)
            print(f"Removing worst individual from population: {GeneticUtils.format_chromossome(worst_individual)}")
            population.remove(worst_individual)

# %% [markdown]
# ## Main

# %%
#import matplotlib.pyplot as plt

if __name__ == "__main__":
    population = []
    for _ in range(10):
        population.append(Chromossome())

    generation = 0
    population_score = Problem.g_average(population)

    generation_plot = []
    generation_plot.append(generation)

    population_score_plot = []
    population_score_plot.append(population_score)

    while generation < 100:
        parent1, parent2 = GeneticOperators.selection(population) # seleciona dois pais

        GeneticOperators.crossover(population, parent1, parent2)  # crossover para gerar dois filhos
        GeneticOperators.mutation(population)                     # chance de mutacao
        GeneticOperators.elitism(population)                      # remove os dois piores da populacao

        generation += 1
        population_score = Problem.g_average(population)

        generation_plot.append(generation)
        population_score_plot.append(population_score)

        print(f"Generation # {generation} -> Average population score = {population_score:.3f}\n")

    best_chromossome = GeneticUtils.find_best_chromossome(population)
    print(f"Best individual: {GeneticUtils.format_chromossome(best_chromossome)}")

    #plt.gca().set_xlabel('Generation')
    #plt.gca().set_ylabel('Average fitness')
    #plt.gca().set_title('Average fitness per generation')
    #plt.plot(generation_plot, population_score_plot)
    #plt.show()
# Out:
# 1st parent chosen for crossover: G = [00100 00010], F = [2, 1], Score = 0.167
# 2nd parent chosen for crossover: G = [01110 01011], F = [7, -5], Score = 0.013
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [01110 01010], F = [7, 5], Score = 0.013
# Removing worst individual from population: G = [01110 01011], F = [7, -5], Score = 0.013
# Removing worst individual from population: G = [01110 01010], F = [7, 5], Score = 0.013
# Generation # 1 -> Average population score = 0.050
#
# 1st parent chosen for crossover: G = [01100 01001], F = [6, -4], Score = 0.019
# 2nd parent chosen for crossover: G = [00100 00010], F = [2, 1], Score = 0.167
# Crossover will happen at point 7
# 1st child generated from crossover: G = [01100 01010], F = [6, 5], Score = 0.016
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [01101 01100], F = [-6, 6], Score = 0.014
# Removing worst individual from population: G = [01100 01010], F = [6, 5], Score = 0.016
# Generation # 2 -> Average population score = 0.069
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [01100 01001], F = [6, -4], Score = 0.019
# Crossover will happen at point 1
# 1st child generated from crossover: G = [01100 01001], F = [6, -4], Score = 0.019
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 01110], F = [2, 7], Score = 0.019
# Removing worst individual from population: G = [01100 01000], F = [6, 4], Score = 0.019
# Generation # 3 -> Average population score = 0.084
#
# 1st parent chosen for crossover: G = [01001 01100], F = [-4, 6], Score = 0.019
# 2nd parent chosen for crossover: G = [01100 01001], F = [6, -4], Score = 0.019
# Crossover will happen at point 6
# 1st child generated from crossover: G = [01001 01001], F = [-4, -4], Score = 0.030
# 2nd child generated from crossover: G = [01100 01100], F = [6, 6], Score = 0.014
# Removing worst individual from population: G = [01100 01100], F = [6, 6], Score = 0.014
# Removing worst individual from population: G = [01001 01100], F = [-4, 6], Score = 0.019
# Generation # 4 -> Average population score = 0.085
#
# 1st parent chosen for crossover: G = [01011 00011], F = [-5, -1], Score = 0.037
# 2nd parent chosen for crossover: G = [01001 01001], F = [-4, -4], Score = 0.030
# Crossover will happen at point 3
# 1st child generated from crossover: G = [01001 01001], F = [-4, -4], Score = 0.030
# 2nd child generated from crossover: G = [01011 00011], F = [-5, -1], Score = 0.037
# Removing worst individual from population: G = [01100 01001], F = [6, -4], Score = 0.019
# Removing worst individual from population: G = [01100 01001], F = [6, -4], Score = 0.019
# Generation # 5 -> Average population score = 0.088
#
# 1st parent chosen for crossover: G = [01101 00111], F = [-6, -3], Score = 0.022
# 2nd parent chosen for crossover: G = [01010 01001], F = [5, -4], Score = 0.024
# Crossover will happen at point 4
# 1st child generated from crossover: G = [01100 01001], F = [6, -4], Score = 0.019
# 2nd child generated from crossover: G = [01011 00111], F = [-5, -3], Score = 0.029
# Removing worst individual from population: G = [01100 01001], F = [6, -4], Score = 0.019
# Removing worst individual from population: G = [01101 00111], F = [-6, -3], Score = 0.022
# Generation # 6 -> Average population score = 0.089
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [01011 00011], F = [-5, -1], Score = 0.037
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [01011 00011], F = [-5, -1], Score = 0.037
# Removing worst individual from population: G = [01010 01001], F = [5, -4], Score = 0.024
# Removing worst individual from population: G = [01011 00111], F = [-5, -3], Score = 0.029
# Generation # 7 -> Average population score = 0.104
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [01001 01001], F = [-4, -4], Score = 0.030
# Removing worst individual from population: G = [01001 01001], F = [-4, -4], Score = 0.030
# Generation # 8 -> Average population score = 0.131
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [01011 00011], F = [-5, -1], Score = 0.037
# Removing worst individual from population: G = [01011 00011], F = [-5, -1], Score = 0.037
# Generation # 9 -> Average population score = 0.157
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [01011 00011], F = [-5, -1], Score = 0.037
# Removing worst individual from population: G = [00100 00010], F = [2, 1], Score = 0.167
# Generation # 10 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 11 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 12 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 13 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 14 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 15 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 16 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 17 -> Average population score = 0.170
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 18 -> Average population score = 0.173
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 19 -> Average population score = 0.177
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 20 -> Average population score = 0.177
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 4
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 21 -> Average population score = 0.177
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 22 -> Average population score = 0.177
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 23 -> Average population score = 0.180
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 24 -> Average population score = 0.180
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 25 -> Average population score = 0.180
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 26 -> Average population score = 0.183
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 27 -> Average population score = 0.183
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 28 -> Average population score = 0.183
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 29 -> Average population score = 0.183
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 30 -> Average population score = 0.190
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 31 -> Average population score = 0.193
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 32 -> Average population score = 0.197
#
# 1st parent chosen for crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Removing worst individual from population: G = [00100 00011], F = [2, -1], Score = 0.167
# Generation # 33 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 34 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Individual G = [00100 00001], F = [2, 0] will mutate at point 7
# Individual G = [00100 00101], F = [2, -2] mutated at point 7
# Removing worst individual from population: G = [00100 00101], F = [2, -2], Score = 0.111
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 35 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 36 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 37 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 38 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 39 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 40 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 41 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 42 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 43 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 44 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 45 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 46 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Individual G = [00100 00001], F = [2, 0] will mutate at point 5
# Individual G = [00100 10001], F = [2, -8] mutated at point 5
# Removing worst individual from population: G = [00100 10001], F = [2, -8], Score = 0.014
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 47 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 4
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 48 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 49 -> Average population score = 0.200
#
# 1st parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd parent chosen for crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Crossover will happen at point 0
# 1st child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Removing worst individual from population: G = [00100 00001], F = [2, 0], Score = 0.200
# Generation # 50 -> Average population score = 0.200
#
# Best individual: G = [00100 00001], F = [2, 0], Score = 0.200
